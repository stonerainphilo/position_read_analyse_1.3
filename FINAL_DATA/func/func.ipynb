# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

def quadratic_fit(csv_file):
    # 读取CSV文件
    data = pd.read_csv(csv_file)
    
    # 假设CSV文件有两列，分别是 x 和 y
    x = data.iloc[:, 0].values
    y = data.iloc[:, 1].values
    
    # 使用numpy进行二次拟合
    coefficients = np.polyfit(x, y, 2)  # 二次多项式拟合
    quadratic_function = np.poly1d(coefficients)
    
    # 打印拟合的二次函数
    print("拟合的二次函数为:")
    print(quadratic_function)
    
    # 可视化原始数据和拟合曲线
    plt.scatter(x, y, color='blue', label='original')  # 原始数据点
    x_fit = np.linspace(min(x), max(x), 500)  # 生成拟合曲线的x值
    y_fit = quadratic_function(x_fit)  # 计算拟合曲线的y值
    plt.plot(x_fit, y_fit, color='red', label='fit')  # 拟合曲线
    plt.xlabel('x')
    plt.ylabel('y')
    plt.xlim(0, 5)
    plt.legend()
    plt.title('fit')
    plt.show()
    
    return coefficients

quadratic_fit('f0_A.csv')
# Out:
# 拟合的二次函数为:
#         2
# 0.5905 x - 0.01571 x + 0.3861
# /home/ubuntu/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 20108 (\N{CJK UNIFIED IDEOGRAPH-4E8C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ubuntu/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ubuntu/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 20989 (\N{CJK UNIFIED IDEOGRAPH-51FD}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ubuntu/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
