# %%
import pandas as pd
import numpy as np

# %%
csv_file = '/media/ubuntu/SRPPS/CODEX-b/CODEX_b-1/mass_1.00e-01_ctau_1.03e+03_br_1.00e+00_seed_1.csv'
df = pd.read_csv(csv_file)
print(df.head())
# Out:
#    Cross_section_pythia  total_events  LLP_number_per_ev  tanb  visible_br  \
# 0              0.423513             0                  1     0    0.001444
# 1              0.423513             0                  2     0    0.001444
# 2              0.423513             0                  3     0    0.001444
# 3              0.423513             0                  4     0    0.001444
# 4              0.390207             1                  5     0    0.001444
#
#    tau_input  decay_pos_z  decay_pos_x  number_of_production  decay_pos_y  \
# 0    1031.12     256128.0   -73708.800                     1     -18657.6
# 1    1031.12     256128.0   -73708.800                     1     -18657.6
# 2    1031.12     389828.0   -39325.600                     1      32207.1
# 3    1031.12     389828.0   -39325.600                     1      32207.1
# 4    1031.12     -37164.1      755.933                     2      49221.5
#
#    seed  Cross_section_fb      tau    m      id
# ...
